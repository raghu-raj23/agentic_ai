# %% [markdown]
# ## Tools
#
# Models -> request -> Tools
# Tools a parings of:
#  1. Schema, including name, desc, args
#  2. Function or coroutine

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="llama3.2", model_provider="ollama")
model
# Out:
# ChatOllama(metadata={'lc_versions': {'langchain-core': '1.4.8', 'langchain': '1.3.11'}}, output_version=None, model='llama3.2')

# %%
from langchain.tools import tool

@tool
def get_weather(location:str) -> str:
    """Get the weather at location"""
    return f"Its sunny in {location}"

model_with_tools = model.bind_tools([get_weather])

# %%
response = model_with_tools.invoke("Whats the weather in Delhi?")
print(response)

for tool_call in response.tool_calls:
    print(f"Tool: {tool_call['name']}")
    print(f"Args: {tool_call['args']}")
# Out:
# content='' additional_kwargs={} response_metadata={'model': 'llama3.2', 'created_at': '2026-06-28T17:30:50.512851Z', 'done': True, 'done_reason': 'stop', 'total_duration': 689465833, 'load_duration': 160341500, 'prompt_eval_count': 154, 'prompt_eval_duration': 85564000, 'eval_count': 18, 'eval_duration': 440502000, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'} id='lc_run--019f0f48-b055-7a43-831d-244e753dd53c-0' tool_calls=[{'name': 'get_weather', 'args': {'location': 'Delhi'}, 'id': '009b8c6e-1bfa-447c-87df-ea2418336716', 'type': 'tool_call'}] invalid_tool_calls=[] usage_metadata={'input_tokens': 154, 'output_tokens': 18, 'total_tokens': 172}
# Tool: get_weather
# Args: {'location': 'Delhi'}
