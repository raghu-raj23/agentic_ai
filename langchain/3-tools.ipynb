# %% [markdown]
# ## Tools
#
# Models -> request -> Tools
# Tools a parings of:
#  1. Schema, including name, desc, args
#  2. Function or coroutine

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="llama3.2", model_provider="ollama")
model
# Out:
# ChatOllama(metadata={'lc_versions': {'langchain-core': '1.4.8', 'langchain': '1.3.11'}}, output_version=None, model='llama3.2')

# %%
from langchain.tools import tool

@tool
def get_weather(location:str) -> str:
    """Get the weather at location"""
    return f"Its sunny in {location}"

model_with_tools = model.bind_tools([get_weather])

# %%
response = model_with_tools.invoke("Whats the weather in Delhi?")
print(response)

for tool_call in response.tool_calls:
    print(f"Tool: {tool_call['name']}")
    print(f"Args: {tool_call['args']}")
# Out:
# content='' additional_kwargs={} response_metadata={'model': 'llama3.2', 'created_at': '2026-07-12T07:29:11.726341Z', 'done': True, 'done_reason': 'stop', 'total_duration': 23066888709, 'load_duration': 21936282334, 'prompt_eval_count': 154, 'prompt_eval_duration': 652085000, 'eval_count': 18, 'eval_duration': 453998000, 'logprobs': None, 'model_name': 'llama3.2', 'model_provider': 'ollama'} id='lc_run--019f553a-8e0a-79f0-b86f-1af4f337e32f-0' tool_calls=[{'name': 'get_weather', 'args': {'location': 'Delhi'}, 'id': '97689682-2e32-4f8a-ae70-caedbc1a3e29', 'type': 'tool_call'}] invalid_tool_calls=[] usage_metadata={'input_tokens': 154, 'output_tokens': 18, 'total_tokens': 172}
# Tool: get_weather
# Args: {'location': 'Delhi'}
